# %% [markdown]
# # ERD Diagram

# %% [markdown]
# ![png](Data/Movies_ERD.png)

# %% [markdown]
# # Imports

# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote
from sqlalchemy.types import *

# %% [markdown]
# # Create the Connection

# %%
import json
with open('/Users/dmusl/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
db_name = "movies"
connection = f"mysql+pymysql://{login['username']}:{urlquote(login['password'])}@localhost/movies"
engine = create_engine(connection)
conn = engine.connect()

# %%
# Previewing the names of all tables 
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies
# 0           genres
# 1          ratings
# 2     title_basics
# 3     title_genres

# %% [markdown]
# ## Foreign Key-Checks

# %%
#Changing the setting for FOREIGN_KEY_CHECKS with the connection
q = """SET @@FOREIGN_KEY_CHECKS=0"""
conn.execute(q)

# %%
# Confirm the checks are deactiavated
q = """SELECT @@FOREIGN_KEY_CHECKS"""
pd.read_sql(q,conn)
# Out:
#    @@FOREIGN_KEY_CHECKS
# 0                     0

# %% [markdown]
# # Import Title Basics

# %%
title_basics = pd.read_csv('Data/title_basics.csv', low_memory=False)
title_basics.info()
title_basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86979 entries, 0 to 86978
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86979 non-null  object
#  1   titleType       86979 non-null  object
#  2   primaryTitle    86979 non-null  object
#  3   originalTitle   86979 non-null  object
#  4   isAdult         86979 non-null  int64
#  5   startYear       86979 non-null  float64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  86979 non-null  int64
#  8   genres          86979 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 6.0+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# Calculate max string lenghts for object columns
tconst_length = title_basics['tconst'].fillna('').map(len).max()
tconst_length
# Out:
# 10

# %%
# Calculate max string lenghts for object columns
title_length = title_basics['primaryTitle'].fillna('').map(len).max()
title_length
# Out:
# 242

# %%
# Checking dataframe's columns
title_basics.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')

# %%
q = '''DESCRIBE title_basics;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#            Field          Type Null  Key            Default  \
# 0         tconst   varchar(12)   NO  PRI               None
# 1  primary_title  varchar(255)  YES                    None
# 2     start_year         float  YES                    None
# 3        runtime           int  YES                    None
# 4     created_at      datetime  YES       CURRENT_TIMESTAMP
# 5     updated_at      datetime  YES       CURRENT_TIMESTAMP
#
#                                            Extra
# 0
# 1
# 2
# 3
# 4                              DEFAULT_GENERATED
# 5  DEFAULT_GENERATED on update CURRENT_TIMESTAMP

# %%
# Rename columns to match SQL table
rename_map = {"primaryTitle":"primary_title",
             "startYear":"start_year",
             "runtimeMinutes":"runtime"}
title_basics = title_basics.rename(rename_map,axis=1)
title_basics.head()
# Out:
#       tconst titleType                                      primary_title  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  start_year  endYear  \
# 0                             Kate & Leopold        0      2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0      2020.0      NaN
# 2                 The Other Side of the Wind        0      2018.0      NaN
# 3                          The Naked Monster        0      2005.0      NaN
# 4                       Crime and Punishment        0      2002.0      NaN
#
#    runtime                  genres
# 0      118  Comedy,Fantasy,Romance
# 1       70                   Drama
# 2      122                   Drama
# 3      100    Comedy,Horror,Sci-Fi
# 4      126                   Drama

# %%
# dropping columns to match the data to the table
titles_table = title_basics.drop(columns=['titleType','originalTitle','isAdult','endYear','genres'])

# %%
# inserting data
titles_table.to_sql("title_basics",conn,index=False, if_exists='append')
# Out:
# 86979

# %%
# confirm the data has been added
q = """SELECT * FROM title_basics;"""
pd.read_sql(q,conn)
# Out:
#           tconst                                      primary_title  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0096056                               Crime and Punishment
# ...          ...                                                ...
# 86974  tt9914942                             Life Without Sara Amat
# 86975  tt9915872                               The Last White Witch
# 86976  tt9916170                                      The Rehearsal
# 86977  tt9916190                                          Safeguard
# 86978  tt9916362                                              Coven
#
#        start_year  runtime          created_at          updated_at
# 0          2001.0      118 2023-10-26 22:59:07 2023-10-26 22:59:07
# 1          2020.0       70 2023-10-26 22:59:07 2023-10-26 22:59:07
# 2          2018.0      122 2023-10-26 22:59:07 2023-10-26 22:59:07
# 3          2005.0      100 2023-10-26 22:59:07 2023-10-26 22:59:07
# 4          2002.0      126 2023-10-26 22:59:07 2023-10-26 22:59:07
# ...           ...      ...                 ...                 ...
# 86974      2019.0       74 2023-10-26 22:59:11 2023-10-26 22:59:11
# 86975      2019.0       97 2023-10-26 22:59:11 2023-10-26 22:59:11
# 86976      2019.0       51 2023-10-26 22:59:11 2023-10-26 22:59:11
# 86977      2020.0       95 2023-10-26 22:59:11 2023-10-26 22:59:11
# 86978      2020.0       92 2023-10-26 22:59:11 2023-10-26 22:59:11
#
# [86979 rows x 6 columns]

# %% [markdown]
# # Import Ratings

# %%
ratings = pd.read_csv('Data/titles_ratings.csv', low_memory=False)
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71900 entries, 0 to 71899
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         71900 non-null  object
#  1   averageRating  71900 non-null  float64
#  2   numVotes       71900 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ MB
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     87153
# 1  tt0062336            6.4       175
# 2  tt0069049            6.7      7754
# 3  tt0088751            5.2       336
# 4  tt0096056            5.6       846

# %%
# Checking dataframe's columns
ratings.columns
# Out:
# Index(['tconst', 'averageRating', 'numVotes'], dtype='object')

# %%
q = '''DESCRIBE ratings;'''
describe = pd.read_sql(q, conn)
describe
# Out:
#              Field         Type Null  Key            Default  \
# 0           tconst  varchar(12)   NO  PRI               None
# 1   average_rating        float  YES                    None
# 2  number_of_votes          int  YES                    None
# 3       updated_at     datetime  YES       CURRENT_TIMESTAMP
# 4       created_at     datetime  YES       CURRENT_TIMESTAMP
#
#                                            Extra
# 0
# 1
# 2
# 3  DEFAULT_GENERATED on update CURRENT_TIMESTAMP
# 4                              DEFAULT_GENERATED

# %%
# Rename columns to match SQL table
rename_map = {"averageRating":"average_rating",
             "numVotes":"number_of_votes"}
ratings = ratings.rename(rename_map,axis=1)
ratings.head()
# Out:
#       tconst  average_rating  number_of_votes
# 0  tt0035423             6.4            87153
# 1  tt0062336             6.4              175
# 2  tt0069049             6.7             7754
# 3  tt0088751             5.2              336
# 4  tt0096056             5.6              846

# %%
# inserting data
ratings.to_sql("ratings",conn,index=False, if_exists='append')
# Out:
# 71900

# %%
# confirm the data has been added
q = """SELECT * FROM ratings;"""
pd.read_sql(q,conn)
# Out:
#           tconst  average_rating  number_of_votes          updated_at  \
# 0      tt0035423             6.4            87153 2023-10-26 23:03:35
# 1      tt0062336             6.4              175 2023-10-26 23:03:35
# 2      tt0069049             6.7             7754 2023-10-26 23:03:35
# 3      tt0088751             5.2              336 2023-10-26 23:03:35
# 4      tt0096056             5.6              846 2023-10-26 23:03:35
# ...          ...             ...              ...                 ...
# 71895  tt9914942             6.6              178 2023-10-26 23:03:38
# 71896  tt9915872             6.4                9 2023-10-26 23:03:38
# 71897  tt9916170             7.0                7 2023-10-26 23:03:38
# 71898  tt9916190             3.7              243 2023-10-26 23:03:38
# 71899  tt9916362             6.4             5422 2023-10-26 23:03:38
#
#                created_at
# 0     2023-10-26 23:03:35
# 1     2023-10-26 23:03:35
# 2     2023-10-26 23:03:35
# 3     2023-10-26 23:03:35
# 4     2023-10-26 23:03:35
# ...                   ...
# 71895 2023-10-26 23:03:38
# 71896 2023-10-26 23:03:38
# 71897 2023-10-26 23:03:38
# 71898 2023-10-26 23:03:38
# 71899 2023-10-26 23:03:38
#
# [71900 rows x 5 columns]

# %% [markdown]
# # Confirm the Database has Been Updated

# %%
# Final view to confirm the names of all tables 
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies
# 0           genres
# 1          ratings
# 2     title_basics
# 3     title_genres

# %%
q = '''DESCRIBE title_basics;'''
describe = pd.read_sql(q, engine)
describe
# Out:
#            Field          Type Null  Key            Default  \
# 0         tconst   varchar(12)   NO  PRI               None
# 1  primary_title  varchar(255)  YES                    None
# 2     start_year         float  YES                    None
# 3        runtime           int  YES                    None
# 4     created_at      datetime  YES       CURRENT_TIMESTAMP
# 5     updated_at      datetime  YES       CURRENT_TIMESTAMP
#
#                                            Extra
# 0
# 1
# 2
# 3
# 4                              DEFAULT_GENERATED
# 5  DEFAULT_GENERATED on update CURRENT_TIMESTAMP

# %%
q= '''SELECT * FROM title_basics LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
#       tconst                                      primary_title  start_year  \
# 0  tt0035423                                     Kate & Leopold      2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...      2020.0
# 2  tt0069049                         The Other Side of the Wind      2018.0
# 3  tt0088751                                  The Naked Monster      2005.0
# 4  tt0096056                               Crime and Punishment      2002.0
#
#    runtime          created_at          updated_at
# 0      118 2023-10-26 22:59:07 2023-10-26 22:59:07
# 1       70 2023-10-26 22:59:07 2023-10-26 22:59:07
# 2      122 2023-10-26 22:59:07 2023-10-26 22:59:07
# 3      100 2023-10-26 22:59:07 2023-10-26 22:59:07
# 4      126 2023-10-26 22:59:07 2023-10-26 22:59:07

# %%
q = '''DESCRIBE ratings;'''
describe = pd.read_sql(q, engine)
describe
# Out:
#              Field         Type Null  Key            Default  \
# 0           tconst  varchar(12)   NO  PRI               None
# 1   average_rating        float  YES                    None
# 2  number_of_votes          int  YES                    None
# 3       updated_at     datetime  YES       CURRENT_TIMESTAMP
# 4       created_at     datetime  YES       CURRENT_TIMESTAMP
#
#                                            Extra
# 0
# 1
# 2
# 3  DEFAULT_GENERATED on update CURRENT_TIMESTAMP
# 4                              DEFAULT_GENERATED

# %%
q= '''SELECT * FROM ratings
LIMIT 5'''
pd.read_sql(q, engine)
# Out:
#       tconst  average_rating  number_of_votes          updated_at  \
# 0  tt0035423             6.4            87153 2023-10-26 23:03:35
# 1  tt0062336             6.4              175 2023-10-26 23:03:35
# 2  tt0069049             6.7             7754 2023-10-26 23:03:35
# 3  tt0088751             5.2              336 2023-10-26 23:03:35
# 4  tt0096056             5.6              846 2023-10-26 23:03:35
#
#            created_at
# 0 2023-10-26 23:03:35
# 1 2023-10-26 23:03:35
# 2 2023-10-26 23:03:35
# 3 2023-10-26 23:03:35
# 4 2023-10-26 23:03:35

# %%
q = '''DESCRIBE genres;'''
describe = pd.read_sql(q, engine)
describe
# Out:
#         Field         Type Null  Key            Default  \
# 0    genre_id          int   NO  PRI               None
# 1  genre_name  varchar(45)  YES                    None
# 2  created_at     datetime  YES       CURRENT_TIMESTAMP
# 3  updated_at     datetime  YES       CURRENT_TIMESTAMP
#
#                                            Extra
# 0                                 auto_increment
# 1
# 2                              DEFAULT_GENERATED
# 3  DEFAULT_GENERATED on update CURRENT_TIMESTAMP

# %%
q= '''SELECT * FROM genres LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
# Empty DataFrame
# Columns: [genre_id, genre_name, created_at, updated_at]
# Index: []

# %%
q = '''DESCRIBE title_genres;'''
describe = pd.read_sql(q, engine)
describe
# Out:
#       Field         Type Null Key Default Extra
# 0    tconst  varchar(45)   NO        None
# 1  genre_id          int   NO        None

# %%
q= '''SELECT * FROM title_genres LIMIT 5;'''
pd.read_sql(q, engine)
# Out:
# Empty DataFrame
# Columns: [tconst, genre_id]
# Index: []
